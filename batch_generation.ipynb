# %%
import os
from langame_client import LangameClient
import random
import openai
from firebase_admin import firestore
#from sentence_transformers import SentenceTransformer
#import numpy as np
#import faiss
import glob

c = LangameClient()

# %%
memes = []
for e in c._firestore_client.collection('memes').stream():
    memes.append((e.id, e.to_dict()))

# %%
len(memes)
# Out:
# 682

# %%
def intersection(lst1, lst2):
    lst3 = [value for value in lst1 if value in lst2]
    return lst3
def get_prompt(topics):
    rnd = random.choices(memes, k=500)
    return [(e[1]['content'], e[1]['topics']) for e in rnd if len(intersection(e[1]['topics'], topics)) > 0]
samples = get_prompt(['mathematic', 'physic', 'knowledge', 'artificial intelligence', 'biology'])

# %%
samples
# Out:
# [('What would happen in an AI-dominated world where similar creativity levels cancel out natural beauty and joy from life???',
#   ['artificial intelligence']),
#  ('"Can an artificial intelligence create art? What does that mean for humans? Should we stop doing art and leave machines to it?"',
#   ['artificial intelligence', 'art', 'philosophy']),
#  ('Does AI communicate with humans in the same way as all other natural language processing techniques or something fundamentally different ?',
#   ['artificial intelligence']),
#  ('What are some of the most radical or outlandish ideas of our time?',
#   ['knowledge']),
#  ('What are your thoughts about the butterfly effect?', ['physic']),
#  ('How did humans first discover mathematical concepts such as 0 or infinity (which seem to be discovered rather than invented)?',
#   ['mathematic']),
#  ('"If you could change the world, would it be more flat or round?"',
#   ['physic']),
#  ('Will human no longer need a job because of artificial intelligence, when people will be rich by working for free? What do you think about the post scarcity paradigm?',
#   ['economy', 'artificial intelligence']),
#  ('What do you think about AI?', ['artificial intelligence']),
#  ('Do you think Memes are what make humans superior to other animals?',
#   ['biology']),
#  ('How is the current market for your type of AI?',
#   ['artificial intelligence']),
#  ('Do you think that it is possible to create a "system" that can be used to predict human behavior?',
#   ['knowledge']),
#  ('If we merge humans with machines, and become cyborgs, what would happen next? (This could lead to a conversation about transhumanism)',
#   ['artificial intelligence', 'transhumanism']),
#  ('Do you think that we can develop a "system" that can be used to predict human behavior?',
#   ['knowledge']),
#  ('With the increasing connectivity brought by the internet, are we slowly becoming a collective intelligence and communist society like ants? What will happen then with brain-computer interfaces?',
#   ['biology',
#    'politic',
#    'transhumanism',
#    'philosophy',
#    'artificial intelligence']),
#  ('How will artificial intelligence quickly help mitigate the impacts of automation disruptions?',
#   ['artificial intelligence']),
#  ('Do you know about dark energy and its effects on the universe as a whole?',
#   ['physic']),
#  ('Can computers think in a human way?\n', ['artificial intelligence']),
#  ('Is it possible for a machine to think?', ['artificial intelligence']),
#  ('Have you learned anything interesting lately?',
#   ['knowledge', 'ice breaker']),
#  (' Do you think it is easier to be a philosopher in ancient times or today?\n',
#   ['knowledge', 'philosophy']),
#  ('Can you have a scientific theory without the word or concept of "matter"?',
#   ['science', 'physic']),
#  ('Have you heard about gravity waves from colliding black holes that were found last year by LIGO experiment ? What do they mean for scientists understanding of physics and astronomy? How can we use them to study nature at extreme scales ?',
#   ['physic']),
#  ('What would happen in an AI-dominated world where similar creativity levels cancel out natural beauty and joy from life???',
#   ['artificial intelligence']),
#  ('What experiments can we do to test ,quantum entanglements and action at a distance?',
#   ['physic']),
#  ('What is knowledge?', ['knowledge']),
#  ('If we merge humans with machines, and become cyborgs, what would happen next? (This could lead to a conversation about transhumanism)',
#   ['artificial intelligence', 'transhumanism']),
#  ('Can artificial intelligence become our next religion, our next God?',
#   ['religion', 'philosophy', 'artificial intelligence']),
#  ('How the Baldwin Effect relates to epistemology?',
#   ['biology', 'philosophy']),
#  ('What is your favorite insect?', ['biology']),
#  ('How the theory of relativity will affect other sciences than physics?',
#   ['science', 'physic']),
#  ('The brighter the light on our path becomes, the more darkness oppresses us... Is it our ability to think/reason and make decisions that moves us toward knowledge/truth or does it lock us into diversion, error and fatality?',
#   ['knowledge', 'philosophy']),
#  ('What do you think is the most interesting thing about the universe?',
#   ['physic', 'science']),
#  (' How do we know that certain is real?\n', ['knowledge']),
#  ('What do you think about the possibility of extraterrestrial life? How do you imagine it would be different from human life?',
#   ['physic', 'philosophy']),
#  ('Are the "facts" that I think I know or believe in, more real than what I don\'t know?',
#   ['knowledge']),
#  (' How do you learn something that interests you ?',
#   ['knowledge', 'ice breaker']),
#  ('Is superluminal speed really unattainable?', ['physic']),
#  ('Do you believe in creationism? How did God create the world according to your religion?',
#   ['biology', 'religion']),
#  ('Which is more advanced, our human-level or their artificial intelligence?',
#   ['artificial intelligence']),
#  ('Should math be a compulsory subject in schools?', ['mathematic']),
#  (' How do we know that certain is real?\n', ['knowledge']),
#  ('How is the human nature different from that of other animals?',
#   ['philosophy', 'biology']),
#  ('"If you could change the world, would it be more flat or round?"',
#   ['physic']),
#  ('Mathematics does not appear to exist; It only seems to exist because humans are able to use their imaginations and mathematical models of reality to predict human behavior accurately as far as we know thus far. However, what if those things do not truly represent reality? What if they are simply metaphors for the way things really are. Then maybe everything uses a metaphor which produces causality?',
#   ['mathematic']),
#  ('Do you believe in creationism? How did God create the world according to your religion?',
#   ['biology', 'religion']),
#  ('Who taught you some basic mathematics first (e.g., multiplication tables or fractions)? What made that person special for teaching them to you?',
#   ['mathematic']),
#  ('Is the universe a random place?', ['physic', 'mathematic']),
#  ('What is the most amazing thing about humans that you have discovered?',
#   ['mathematic', 'ice breaker']),
#  ('What do you think about AI?', ['artificial intelligence']),
#  ('What are your thoughts about the butterfly effect?', ['physic']),
#  ('What is knowledge?', ['knowledge']),
#  (" What do you think of the idea that one can be in love with one's own creation?\n",
#   ['biology', 'philosophy']),
#  ('"I know that you know that I know that you know the answer to this."\n"I know that you know a lot of things, but I don\'t know what you know about _____."\n"I know that you know that I know that you know the answer to this."\n"I know that you know that I know what I know."',
#   ['knowledge']),
#  ('Will human no longer need a job because of artificial intelligence, when people will be rich by working for free? What do you think about the post scarcity paradigm?',
#   ['economy', 'artificial intelligence']),
#  ('What is the full form of F = ma ?', ['physic']),
#  ('What is the role of emotions in decision making?', ['knowledge']),
#  ('What is mathematics?', ['mathematic']),
#  ('What is knowledge?', ['knowledge']),
#  ('Do you believe that one day robots could have feelings and emotions as humans do now ? If yes, what kind of feelings for example love or hate should they have if we want them to behave like humans without being considered monsters by other people ?',
#   ['artificial intelligence']),
#  ('How the theory of relativity will affect other sciences than physics?',
#   ['science', 'physic']),
#  ('What is the role of religious education in our society?',
#   ['knowledge', 'religion']),
#  ('The brighter the light on our path becomes, the more darkness oppresses us... Is it our ability to think/reason and make decisions that moves us toward knowledge/truth or does it lock us into diversion, error and fatality?',
#   ['knowledge', 'philosophy']),
#  ('Since consciousness exists in machines too, will we reach a point of singularity where a machine becomes conscious, accesses all human knowledge and creates a new civilization? What are some of the potential risks/risks of such an event?',
#   ['artificial intelligence']),
#  ('What could gravitational waves be used for?', ['physic']),
#  ('Does nature play fair? Or even care?', ['philosophy', 'biology']),
#  ('Is it a possibility that the state become governed by an artificial intelligence?',
#   ['politic', 'artificial intelligence', 'transhumanism']),
#  ('What are the most important mathematical discoveries in history, or which was the best mathematician ever?',
#   ['mathematic']),
#  ('Since consciousness exists in machines too, will we reach a point of singularity where a machine becomes conscious, accesses all human knowledge and creates a new civilization? What are some of the potential risks/risks of such an event?',
#   ['artificial intelligence']),
#  ('Do you think artificial intelligence have sense to be conscious, if so. If not compute capability? Which is more fundamental?',
#   ['artificial intelligence']),
#  ('Can you have a scientific theory without the word or concept of "matter"?',
#   ['science', 'physic']),
#  ('Do you believe in the theory of relativity?', ['physic']),
#  ('Is it possible that our next religion is going to be artificial intelligence? Can we create God?',
#   ['transhumanism', 'religion', 'artificial intelligence']),
#  ('What do you think of the big bang theory?', ['physic', 'science']),
#  ('Do you think artificial intelligence have sense to be conscious, if so. If not compute capability? Which is more fundamental?',
#   ['artificial intelligence']),
#  ('Do you know who invented numbers ?', ['mathematic']),
#  ('How will artificial intelligence quickly help mitigate the impacts of automation disruptions?',
#   ['artificial intelligence']),
#  ('Have you heard about gravity waves from colliding black holes that were found last year by LIGO experiment ? What do they mean for scientists understanding of physics and astronomy? How can we use them to study nature at extreme scales ?',
#   ['physic']),
#  ('What makes a great conversation?', ['knowledge']),
#  (' What do you know about the Red Queen Effect?', ['biology']),
#  ("Which components of a plant is useless for human's health, and why?",
#   ['health', 'biology']),
#  ("Is human intelligence superior because of its ability to reason using logic ? Yet computers can also reason logically… However, they don't appear able think outside their programming/structure; whereas humans can spontaneously imagine new possibilities ... Can machines reach this highest possible level through continued evolution or will they always be limited by their structure just like animals are limited by theirs? Will AI ever reach consciousness , intuition , imagination …etc.? Do any computer programs currently exist which mimic the above characteristics enough so that people mistake them for human beings???",
#   ['mathematic', 'artificial intelligence']),
#  ('Do you believe in the theory of the Selfish gene?', ['biology']),
#  ('What is the most incredible thing you have ever seen?',
#   ['ice breaker', 'artificial intelligence']),
#  ('Will artificial intelligence reveal our identity publicly',
#   ['mind', 'artificial intelligence']),
#  ('Who are you? (Where did you come from?)', ['mathematic', 'ice breaker']),
#  ('Do you believe in creationism? How did God create the world according to your religion?',
#   ['biology', 'religion']),
#  ('Are the "facts" that I think I know or believe in, more real than what I don\'t know?',
#   ['knowledge']),
#  ('Do you have any phobias or fears related to animals? If so, what are they?',
#   ['biology']),
#  ('Do you think that we can develop a "system" that can be used to predict human behavior?',
#   ['knowledge']),
#  ('What are the technical aspects and challenges of space exploration?',
#   ['space exploration', 'physic']),
#  ('What is a human?', ['biology']),
#  ('Do you know about dark energy and its effects on the universe as a whole?',
#   ['physic']),
#  ("Do you think that it's possible to create a conscious machine with full rights like humans have?",
#   ['artificial intelligence']),
#  ('What would be your personal theory about how life started on Earth?',
#   ['science', 'biology']),
#  ('What would be your personal theory about how life started on Earth?',
#   ['science', 'biology']),
#  ('What did you learn today? Write down your answer and think it again tomorrow?',
#   ['knowledge']),
#  ('What would be your personal theory about how life started on Earth?',
#   ['science', 'biology']),
#  ('What should be taught about math in school and what should be left out? How can one make sure students understand how to do real-world math with a foundation on abstract concepts?" Not much really needs to be added here; this says it all - but I\'ll add my own two cents: Mathematics has been an integral part of human society since at least prehistory, because accounting (keeping track of resources) is absolutely necessary for any kind of civilization. This fact alone probably makes math "the driving force" behind human existence (for example, both language and art are also essential parts of primitive civilizations). Abstract thinking comes naturally as a result (for example, people made geometry long before they had writing), so once civilization becomes sophisticated enough to need more than just food & shelter then there\'s no way around it - you\'re forced into abstract thought eventually whether you like it or not...and if your civilization survives long enough without having done so then chances are that you\'re screwed anyway...so why bother resisting? Of course even today there\'s nothing wrong with using mental shortcuts ("intuitions") when doing things quickly just because "your gut tells you" something will work: You don\'t have time anymore for deep analysis during everyday life unless there isn\'t any other option anyways - nobody stops their car at red lights anymore either because everybody knows from experience that cars stop by themselves once "green light" means \'go\'... Moreover science itself shows us clearly where these intuitions come from: Every theory/model etc. works only given certain restrictions (= assumptions) , i.e., every such model consists exactly of those elements which lead logically from given premises (= axioms ) ; everything else must simply be thrown away or considered irrelevant . And indeed most intuition arises due to knowing something firsthand yourself; e g., learning calculus requires actually drawing some curves first before seeing them graphically depicted later on , whereas solving differential equations often involves some idea similar to Newton\'s method but applied after translating the equation into another form first . In other words practice plays a big role in forming our ideas about nature! But unfortunately many people seem unable or unwilling nowadays even think specifically about physics problems anymore *or* ask questions like posed above....',
#   ['mathematic', 'science']),
#  ('How is mathematics relevant in the real world?', ['mathematic']),
#  ('What do you think of the theory that animals have emotions?', ['biology']),
#  ('What is the full form of F = ma ?', ['physic']),
#  ('"Now, let\'s consider the root of mathematics. What are numbers?',
#   ['mathematic']),
#  ("What's the difference between knowledge, wisdom, and understanding?",
#   ['wellness', 'knowledge']),
#  ('What would the world be like without any form of government?',
#   ['philosophy', 'politic', 'knowledge']),
#  ('How do we know that the universe is real?',
#   ['mind', 'knowledge', 'physic', 'science']),
#  ('What is knowledge?', ['knowledge']),
#  ('How business relates to the theory of evolution by natural selection?',
#   ['biology', 'business', 'startup']),
#  ("Is human intelligence superior because of its ability to reason using logic ? Yet computers can also reason logically… However, they don't appear able think outside their programming/structure; whereas humans can spontaneously imagine new possibilities ... Can machines reach this highest possible level through continued evolution or will they always be limited by their structure just like animals are limited by theirs? Will AI ever reach consciousness , intuition , imagination …etc.? Do any computer programs currently exist which mimic the above characteristics enough so that people mistake them for human beings???",
#   ['mathematic', 'artificial intelligence']),
#  ('What do you think about the movie "Her"?', ['artificial intelligence']),
#  ('Are there any \'fundamental\' laws or equations (such as F=ma) that have emerged from studying math throughout history? And if so, can you explain how this happened to us human beings - why was it we who found these fundamental laws of nature?"',
#   ['mathematic']),
#  ('How can we create an artificial intelligence that is not tainted by the deep-seated biases of human nature?',
#   ['artificial intelligence']),
#  ('Which is your favorite branch of mathematics (arithmetic, algebra, geometry, trigonometry)? Why?',
#   ['mathematic']),
#  ('Do you believe in the theory of the Selfish gene?', ['biology']),
#  ('What is a unit circle? How many points are there on it and how many lines can be drawn through it?',
#   ['mathematic']),
#  ('Have you heard about gravity waves from colliding black holes that were found last year by LIGO experiment ? What do they mean for scientists understanding of physics and astronomy? How can we use them to study nature at extreme scales ?',
#   ['physic']),
#  (' What is the role of faith in religious and non-religious societies?\n',
#   ['knowledge', 'religion']),
#  ('How do you choose books to read?A book is much like traveling; see the area with your own eyes, hear about it and the whole while digesting the information that it holds.',
#   ['knowledge', 'book']),
#  ('What is the most incredible thing you have ever seen?',
#   ['ice breaker', 'artificial intelligence']),
#  ('What maths topics would be interesting to explore and how can we learn more about them ?',
#   ['mathematic']),
#  ('Have you learned anything interesting lately?',
#   ['knowledge', 'ice breaker']),
#  ('Many mathematicians have been working throughout history trying to understand why some numbers are more useful than others and how these came into being . Answering this questions may lead us to good discussions on the nature of existence and artificiality of science . We could also find similarities between mathematics and music , which is another topic very related with numbers . The objective here isn\'t just knowledge; I believe knowing things helps develop reasoning skills , not only memorizing information from books or internet articles. 3. Have you ever heard of prime numbers ? What do they mean ? Prime number s are natural number s greater than 1 whose only positive divisors are itself \xa0and 1 : 2 , 3 , 5 , 7 , 11 … A simple way to explain them in a short way: \xa0prime number s can easily be divided into equal groups without any remainder : 4 = 2 * 2 8 = 4 * 2 16 = 8 * 2 32 = 16*2 64= 32*2 128= 64*32 256=128*16 512=256*32 1024=(256+64)*16 2048=(128+64)*(16×4) 4096=(256+64)(8×4) ×(1+(8)) 2401609600896144000245760000… So primes look like single unbreakable structures since they cannot be split among several parts (without leaving any remainder). You might ask yourself now: "What kind of use does having prime number s has?" One fun thing with prime numbe rs is that they appear all over nature: Primes never repeat themselves so each whole number can be uniquely described using just their digits \xa0 - No matter how far out one goes in measuring distances along straight lines each distance will always fall under one specific prime \xa0 - Einstein proved that every atom consists purely out energy',
#   ['mathematic']),
#  ('Do you think that if we developed artificial intelligence it would be rational or irrational ? Why ?\n',
#   ['artificial intelligence', 'philosophy']),
#  ('Do you have any phobias or fears related to animals? If so, what are they?',
#   ['biology']),
#  ('Which film, book or TV program on AI impressed you most and why did it impress you so much? How would a movie like "The Terminator" appear to be if it really happened today ?',
#   ['artificial intelligence']),
#  ("What's the difference between knowledge, wisdom, and understanding?",
#   ['wellness', 'knowledge']),
#  ('Do you know who invented numbers ?', ['mathematic']),
#  ('From age old traditions to modern science, can nature be reduced to random processes? Does nature have its own random variables, distributions, and games with hidden meanings, towards higher dimensional orders of non-linearity?',
#   ['mathematic', 'philosophy']),
#  ('What is a person? Is it a community? Is it something else?', ['biology']),
#  ('What do you think is the most interesting thing about the universe?',
#   ['physic', 'science']),
#  ('What do you think about the movie "Her"?', ['artificial intelligence']),
#  ('Do you think math is a hard subject? Why or why not?', ['mathematic']),
#  ('How does knowledge affect our perception of the world?', ['knowledge']),
#  ("Philosophy is a study of some of life's biggest questions. But can you do philosophy without an answer to these questions?",
#   ['knowledge', 'philosophy']),
#  ('How does one recognize truth and knowledge', ['knowledge', 'philosophy']),
#  ('Which is the main purpose of artificial intelligence in your opinion, what will it help us to achieve?',
#   ['artificial intelligence']),
#  ('Many mathematicians have been working throughout history trying to understand why some numbers are more useful than others and how these came into being . Answering this questions may lead us to good discussions on the nature of existence and artificiality of science . We could also find similarities between mathematics and music , which is another topic very related with numbers . The objective here isn\'t just knowledge; I believe knowing things helps develop reasoning skills , not only memorizing information from books or internet articles. 3. Have you ever heard of prime numbers ? What do they mean ? Prime number s are natural number s greater than 1 whose only positive divisors are itself \xa0and 1 : 2 , 3 , 5 , 7 , 11 … A simple way to explain them in a short way: \xa0prime number s can easily be divided into equal groups without any remainder : 4 = 2 * 2 8 = 4 * 2 16 = 8 * 2 32 = 16*2 64= 32*2 128= 64*32 256=128*16 512=256*32 1024=(256+64)*16 2048=(128+64)*(16×4) 4096=(256+64)(8×4) ×(1+(8)) 2401609600896144000245760000… So primes look like single unbreakable structures since they cannot be split among several parts (without leaving any remainder). You might ask yourself now: "What kind of use does having prime number s has?" One fun thing with prime numbe rs is that they appear all over nature: Primes never repeat themselves so each whole number can be uniquely described using just their digits \xa0 - No matter how far out one goes in measuring distances along straight lines each distance will always fall under one specific prime \xa0 - Einstein proved that every atom consists purely out energy',
#   ['mathematic']),
#  ("Philosophy is a study of some of life's biggest questions. But can you do philosophy without an answer to these questions?",
#   ['knowledge', 'philosophy']),
#  ('What is the point of mathematics?',
#   ['mathematic', 'knowledge', 'philosophy']),
#  ('What do you think about the "knowledge economy"?', ['knowledge']),
#  ('What are the technical aspects and challenges of space exploration?',
#   ['space exploration', 'physic']),
#  ('Can computers feel emotions?', ['artificial intelligence']),
#  ('At what point does one qualify as sentient. Is AI certainly within the bounds of sentience or does it exceed any league?',
#   ['philosophy', 'artificial intelligence']),
#  ('What would the world be like without any form of government?',
#   ['philosophy', 'politic', 'knowledge']),
#  (' How do you learn something that interests you ?',
#   ['knowledge', 'ice breaker']),
#  ('Why are humans interested in philosophy?', ['philosophy', 'knowledge']),
#  ('What do you think about the possibility of extraterrestrial life? How do you imagine it would be different from human life?',
#   ['physic', 'philosophy']),
#  ('Quantum connection is instantaneous, that is, faster than light, isn’t it paradoxical?',
#   ['physic']),
#  ('What are your thoughts about the butterfly effect', ['physic']),
#  ('Can computers think in a human way?\n', ['artificial intelligence']),
#  ('What was the last math problem you solved?', ['mathematic']),
#  ('Do you think we will still use the same mathematics when we merge with machines?',
#   ['mathematic', 'knowledge', 'transhumanism', 'artificial intelligence']),
#  ('What is the most interesting fact you learned in biology class?',
#   ['biology']),
#  ('What is a human?', ['biology']),
#  ('Have you seen any science fiction movie like Interstellar, Contact etc.? Are there any movies out there that inspired you to learn more about theoretical physics (like wormholes, time machines or other dimensions)?',
#   ['physic']),
#  ('What would happen in an AI-dominated world where similar creativity levels cancel out natural beauty and joy from life???',
#   ['artificial intelligence']),
#  ('Is there something that you are not sure about?',
#   ['knowledge', 'ice breaker', 'philosophy']),
#  ('Which film, book or TV program on AI impressed you most and why did it impress you so much? How would a movie like "The Terminator" appear to be if it really happened today ?',
#   ['artificial intelligence']),
#  ("Does AI's imagination become more creative than humans or I’m just biased?",
#   ['artificial intelligence']),
#  (' How do you define intelligence?\n',
#   ['artificial intelligence', 'philosophy', 'knowledge']),
#  ('If you had unlimited knowledge, what would your life look like?',
#   ['knowledge', 'philosophy', 'ice breaker']),
#  ('What is the best thing you have learned about philosophy?',
#   ['philosophy', 'knowledge']),
#  ("Do you think that it's possible to create a conscious machine with full rights like humans have?",
#   ['artificial intelligence']),
#  ("What do you know about Einstein's theory of relativity? Which do you prefer and why ? \xa0 [The reason for asking this question is that it can help us understand if we are dealing with an AI pretending to be human]",
#   ['mathematic', 'physic', 'science']),
#  ('"Now, let\'s consider the root of mathematics. What are numbers?',
#   ['mathematic']),
#  ('What would the world be like without any form of government?',
#   ['philosophy', 'politic', 'knowledge']),
#  ('What is your favorite insect?', ['biology']),
#  ('If you could know the answer to any question. What would it be?',
#   ['knowledge', 'philosophy']),
#  ('Is the universe a random place?', ['physic', 'mathematic']),
#  ('How will humans distinguish themselves from an intelligent machine?',
#   ['artificial intelligence']),
#  ('Does nature play fair? Or even care?', ['philosophy', 'biology']),
#  (' God is dead   -> Does that mean we cannot find a new god?   -> If we could create an AI God, what would it look like?   -> How would it affect religion?',
#   ['religion', 'artificial intelligence']),
#  ('What is your favorite number?', ['mathematic']),
#  ('Is it a possibility that the state become governed by an artificial intelligence?',
#   ['politic', 'artificial intelligence', 'transhumanism']),
#  ('Is the universe a random place?', ['physic', 'mathematic']),
#  (" What do you think of the idea that one can be in love with one's own creation?\n",
#   ['biology', 'philosophy']),
#  ('Do you believe we, humans, are just biological machines made of meat?',
#   ['biology']),
#  ('Is the universe a random place?', ['physic', 'mathematic']),
#  ('What is the ideal human-AI symbiotic relationship?',
#   ['artificial intelligence']),
#  ("What is the value of living one's life?",
#   ['artificial intelligence', 'philosophy']),
#  ('How is the human nature different from that of other animals?',
#   ['philosophy', 'biology']),
#  ('What do you think would be the main characteristics of a society which lives in accordance with nature, whereas our society does not meet most of its needs through nature?',
#   ['knowledge', 'ecology', 'philosophy', 'politic']),
#  ('How do you know that your senses accurately reflect reality?',
#   ['knowledge']),
#  ('From age old traditions to modern science, can nature be reduced to random processes? Does nature have its own random variables, distributions, and games with hidden meanings, towards higher dimensional orders of non-linearity?',
#   ['mathematic', 'philosophy'])]

# %%
n_m = [
    ("If any kind of AI is supposedly great, where would it have its main limitation? Would that limit depend on government regulation or poor corresponding laws?",['artificial intelligence']),
    ("Quantum Entanglement solves many problems like energy creation without more physical material than can be at most one atom apart...So I read it. Can you give me some proofs?", ['physic']),
    ('Is what comes out of Newton\'s prism true even if this was cast aside in favour of quantum mechanics & quantized reality. Quantum physics under certain circumstances allow relativity theory, which is not classical can it be seen as contradictory or are space-time constantly being disrupted by E = mc^2.',['mathematic']),
    ("I could say that AI will ‘blow us out of the water’ in terms of computational power by 2030.. but have you considered what are its technological requirements ?", ['physic']),
    ('Do we own our identity and thoughts or is there more we don’t know?',['philosophy','mind']),
    ('Do you think the human brain will ever be quantified ?', ['mathematic']),
    ('Does language affect the ways that one thinks and how do you think differently simply because of this. Is there a way to weigh pros and cons without basing onesifications on religious influence i suppose.',['artificial intelligence']),
    ('Will computers inevitably simulate consciousness in some wierd way. That might be induced by something else that you have no idea about…. Are certain words semantics ad information theory which are being processed not neural connections ?\n .. what was “bold” to schopenhauer when introducing the subject of change , he saw it as ridiculous.',['artificial intelligence'] ),
    ('If all things are continuous do not exist what makes them separate ?', ['mathematic','philosophy']),
    ('What would happen given that physcals design our machines to last forever. was it the moral conduct or physical predilection for discovery? ',['physic']),
    ('What happens inside the black hole?',['physic','mathematic']),
    ("stars are dying, does that mean something musn't you think?",['knowledge']),
    ('Is there any indication about how our universe will end ?',['physic','mathematic']),
    ("can machines earn ethics. How should't they be designed to do that first?", ['artificial intelligence', 'knowledge'] ),
    ("If you wanted a useful definition of 'intelligence', precisely how would one quantify all combination abilities? For example, I have the experience with 2 numbers being added but not able to sing along - this kind/experience can it exist or does nature deny us for any complex intuitive processes.",['mind', 'psychology']),
    ("Does society control what we do with our time?", ["mind"]),
    ('What can you really expect from a logical consistent theory?', ['philosophy']),
    ('Can human existence be explained by chance alone, is there any conceivable explanation for nature ?', ["biology"]),
    ('What happens if our environment gets so polluted the only way we can survive is by destroying ourselves?', ["biology"]),
    ('What is the point of mathematics?', ['mathematic', 'knowledge', 'philosophy']),
    ('Do you think we will still use the same mathematics when we merge with machines?', ['mathematic', 'knowledge', 'transhumanism', 'artificial intelligence']),
    ('If you had unlimited knowledge, what would your life look like?', ['knowledge', 'philosophy', 'ice breaker']),
    ('Is there anything that can be mathematically described but not understood with our intelligence?', ['mathematic']),
    ("Which subjects would you prefer to receive a PhD in if there was no limit on your choice of subject?",  ['knowledge', 'philosophy', 'psychology']),
    ("Which fictional character do you most identify with ?", ['ice breaker']),
]

# %%
sentences = ["How will humans distinguish themselves from an intelligent machine", "Is artificial intelligence an expression of human nature or does it violate basic principles that the programming was based on ?"]

model = SentenceTransformer('sentence-transformers/paraphrase-xlm-r-multilingual-v1')
embeddings = model.encode(sentences)
print(embeddings)

# %%
model = SentenceTransformer('all-mpnet-base-v2')
embeddings = [model.encode(e[1]['content']) for e in memes]

# %%
np.save("embeddings/part1.npy", embeddings)

# %%
quantizer = Quantizer()
quantizer.quantize(embeddings_path="embeddings", output_path="my_index_folder", max_index_memory_usage="4G", current_memory_available="4G")

# %%
my_index = faiss.read_index(glob.glob("my_index_folder/*.index")[0])

query_vector = np.float32(np.random.rand(1, 100))
k = 5
distances, indices = my_index.search(query_vector, k)

print(list(zip(distances[0], indices[0])))

# %%
def is_valid():
    invalids = []
    for e in n_m:
        if not isinstance(e[0], str) or not isinstance(e[1], list):
            invalids.append(e)
    return invalids

# %%
is_valid()
# Out:
# []

# %%
for e in n_m:
    d = {
        'content': e[0], 
        'topics': e[1],
        'disabled': False,
        'createdAt': firestore.SERVER_TIMESTAMP,
        'tweet': True,
    }
    c._firestore_client.collection('memes').add(d)
